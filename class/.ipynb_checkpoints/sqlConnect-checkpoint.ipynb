# %%
# !pip install psycopg2-binary

# %%
# !pip install netifaces
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for netifaces: filename=netifaces-0.11.0-cp311-cp311-linux_x86_64.whl size=14222 sha256=64b77717af587bf264f3674e76dd7be816541aeb2c9a00f838c36d060bd16c06
#   Stored in directory: /home/jovyan/.cache/pip/wheels/40/85/29/648c19bbbb5f1d30e33bfb343fd7fb54296b402f7205d8e46f
# Successfully built netifaces
# ...

# %%
conn = connect_to_database()
# Out:
# Error al conectar a la base de datos: connection to server at "172.20.0.3", port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?

# %%
from database_connection import *

# %%
conn = connect_to_database()

# %%
from crud_operations import *

# %%
select_query(conn, "select * from cinema.films")
# Out:
# [(1,
#   "Intolerance: Love's Struggle Throughout the Ages",
#   1916,
#   'USA',
#   123,
#   None,
#   'Not Rated',
#   None,
#   385907),
#  (2,
#   'Over the Hill to the Poorhouse',
#   1920,
#   'USA',
#   110,
#   None,
#   None,
#   3000000,
#   100000),
#  (3, 'The Big Parade', 1925, 'USA', 151, None, 'Not Rated', None, 245000),
#  (4,
#   'Metropolis',
#   1927,
#   'Germany',
#   145,
#   'German',
#   'Not Rated',
#   26435,
#   6000000),
#  (5, "Pandora's Box", 1929, 'Germany', 110, 'German', 'Not Rated', 9950, None),
#  (6,
#   'The Broadway Melody',
#   1929,
#   'USA',
#   100,
#   'English',
#   'Passed',
#   2808000,
#   379000),
#  (7, "Hell's Angels", 1930, 'USA', 96, 'English', 'Passed', None, 3950000),
#  (8,
#   'A Farewell to Arms',
#   1932,
#   'USA',
#   79,
#   'English',
#   'Unrated',
#   None,
#   800000),
#  (9, '42nd Street', 1933, 'USA', 89, 'English', 'Unrated', 2300000, 439000),
#  (10,
#   'She Done Him Wrong',
#   1933,
#   'USA',
#   66,
# ...
