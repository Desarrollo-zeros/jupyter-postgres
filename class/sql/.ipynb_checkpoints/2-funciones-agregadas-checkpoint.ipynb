# %%
SELECT SUM(budget) FROM cinema.films;
# Out:
#             sum
# 0  181079025606

# %%
select sum(duration) from cinema.films
# Out:
#       sum
# 0  534882

# %%
select avg(duration) from cinema.films
# Out:
#           avg
# 0  107.947931

# %%
select min(duration) from cinema.films
# Out:
#    min
# 0    7

# %%
select max(duration) from cinema.films
# Out:
#    max
# 0  334

# %%
SELECT SUM(budget) FROM cinema.films WHERE release_year >= 2010;
# Out:
#            sum
# 0  54913578440

# %%
select sum(gross) from cinema.films where release_year >= 2000
# Out:
#             sum
# 0  150900926358

# %%
SELECT SUM(gross)-SUM(budget) as diferencia FROM cinema.films WHERE release_year >= 2010;
# Out:
#     diferencia
# 0  12210755797

# %%
select avg(gross) from cinema.films where title like 'A%'
# Out:
#             avg
# 0  4.789324e+07

# %%
select min(gross) from cinema.films where release_year = '1994'
# Out:
#       min
# 0  125169

# %%
select max(gross) from cinema.films where release_year between 2000 and 2012
# Out:
#          max
# 0  760505847

# %%
SELECT MAX(budget) AS max_budget, MAX(duration) AS max_duration FROM cinema.films;
# Out:
#     max_budget  max_duration
# 0  12215500000           334

# %%
SELECT title, gross - budget AS net_profit FROM cinema.films
# Out:
#                                                  title  net_profit
# 0     Intolerance: Love's Struggle Throughout the Ages         NaN
# 1                       Over the Hill to the Poorhouse   2900000.0
# 2                                       The Big Parade         NaN
# 3                                           Metropolis  -5973565.0
# 4                                        Pandora's Box         NaN
# ...                                                ...         ...
# 4963                                       Unforgotten         NaN
# 4964                                             Wings         NaN
# 4965                                        Wolf Creek         NaN
# 4966                                 Wuthering Heights         NaN
# 4967                           Yu-Gi-Oh! Duel Monsters         NaN
#
# [4968 rows x 2 columns]

# %%
select title, duration / 60.0 as duration_hours from cinema.films
# Out:
#                                                  title  duration_hours
# 0     Intolerance: Love's Struggle Throughout the Ages        2.050000
# 1                       Over the Hill to the Poorhouse        1.833333
# 2                                       The Big Parade        2.516667
# 3                                           Metropolis        2.416667
# 4                                        Pandora's Box        1.833333
# ...                                                ...             ...
# 4963                                       Unforgotten        0.750000
# 4964                                             Wings        0.500000
# 4965                                        Wolf Creek             NaN
# 4966                                 Wuthering Heights        2.366667
# 4967                           Yu-Gi-Oh! Duel Monsters        0.400000
#
# [4968 rows x 2 columns]

# %%
select avg(duration) as avg_duration_hours from cinema.films
# Out:
#    avg_duration_hours
# 0          107.947931

# %%
select avg(duration)/60.0 as avg_duration_hours from cinema.films
# Out:
#    avg_duration_hours
# 0            1.799132

# %%
select count(deathdate) * 100.0/count(*) as percentage_dead from cinema.people
# Out:
#    percentage_dead
# 0         9.372395

# %%
SELECT MAX(release_year) - MIN(release_year) AS difference FROM cinema.films
# Out:
#    difference
# 0         100

# %%
SELECT (MAX(release_year) - MIN(release_year)) / 10.0 AS number_of_decades FROM cinema.films
# Out:
#    number_of_decades
# 0               10.0

# %%
select count(*) from cinema.films where cinema.films.language is null
# Out:
#    count
# 0      0

# %%
select * from cinema.films where cinema.films.language=''
# Out:
#       id  ...      budget
# 0      1  ...    385907.0
# 1      2  ...    100000.0
# 2      3  ...    245000.0
# 3    208  ...   4400000.0
# 4   2624  ...   3000000.0
# 5   2875  ...  11000000.0
# 6   4347  ...   1000000.0
# 7   4358  ...   7000000.0
# 8   4866  ...  17000000.0
# 9   4927  ...         NaN
# 10  4963  ...         NaN
#
# [11 rows x 9 columns]

# %%
select * from cinema.films where cinema.films.language like'% %'
# Out:
# Empty DataFrame
# Columns: [id, title, release_year, country, duration, language, certification, gross, budget]
# Index: []
