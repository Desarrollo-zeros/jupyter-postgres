# %%
SELECT title,release_year FROM cinema.films WHERE release_year BETWEEN 1994 AND 2000
# Out:
#                           title  release_year
# 0            3 Ninjas Kick Back          1994
# 1        A Low Down Dirty Shame          1994
# 2    Ace Ventura: Pet Detective          1994
# 3                Baby's Day Out          1994
# 4         Beverly Hills Cop III          1994
# ..                          ...           ...
# 809                     Whipped          2000
# 810                Woman on Top          2000
# 811                 Wonder Boys          2000
# 812                       X-Men          2000
# 813         You Can Count on Me          2000
#
# [814 rows x 2 columns]

# %%
SELECT title, release_year from cinema.films where release_year between 1990 and 2000
# Out:
#                            title  release_year
# 0                  Arachnophobia          1990
# 1    Back to the Future Part III          1990
# 2                 Child's Play 2          1990
# 3             Dances with Wolves          1990
# 4                Days of Thunder          1990
# ..                           ...           ...
# 952                      Whipped          2000
# 953                 Woman on Top          2000
# 954                  Wonder Boys          2000
# 955                        X-Men          2000
# 956          You Can Count on Me          2000
#
# [957 rows x 2 columns]

# %%
SELECT title, release_year FROM cinema.films WHERE release_year BETWEEN 1990 AND 2000 AND budget > 100000000
# Out:
#                                         title  release_year
# 0                  Terminator 2: Judgment Day          1991
# 1                                   True Lies          1994
# 2                                  Waterworld          1995
# 3                              Batman & Robin          1997
# 4                                Dante's Peak          1997
# 5                           Princess Mononoke          1997
# 6                     Speed 2: Cruise Control          1997
# 7                           Starship Troopers          1997
# 8                                     Titanic          1997
# 9                         Tomorrow Never Dies          1997
# 10                               A Bug's Life          1998
# 11                                       Antz          1998
# 12                                 Armageddon          1998
# 13    Les couloirs du temps: Les visiteurs II          1998
# 14                            Lethal Weapon 4          1998
# ...

# %%
SELECT title, release_year FROM cinema.films WHERE release_year BETWEEN 1990 AND 2000 AND budget > 100000000 and language = 'Spanish'
# Out:
#    title  release_year
# 0  Tango          1998

# %%
SELECT title, release_year FROM cinema.films WHERE release_year BETWEEN 1990 AND 2000 AND budget > 100000000 AND (language = 'Spanish' or language = 'French');
# Out:
#                                      title  release_year
# 0  Les couloirs du temps: Les visiteurs II          1998
# 1                                    Tango          1998

# %%
select title, release_year from cinema.films where release_year in (1990, 2000)
# Out:
#                            title  release_year
# 0                  Arachnophobia          1990
# 1    Back to the Future Part III          1990
# 2                 Child's Play 2          1990
# 3             Dances with Wolves          1990
# 4                Days of Thunder          1990
# ..                           ...           ...
# 196                      Whipped          2000
# 197                 Woman on Top          2000
# 198                  Wonder Boys          2000
# 199                        X-Men          2000
# 200          You Can Count on Me          2000
#
# [201 rows x 2 columns]

# %%
select title, release_year from cinema.films where release_year in (1990, 2000) and duration > 120
# Out:
#                          title  release_year
# 0           Dances with Wolves          1990
# 1                   Die Hard 2          1990
# 2                        Ghost          1990
# 3                   Goodfellas          1990
# 4             Mo' Better Blues          1990
# 5                 Pretty Woman          1990
# 6      The Godfather: Part III          1990
# 7     The Hunt for Red October          1990
# 8        All the Pretty Horses          2000
# 9                Almost Famous          2000
# 10                  Bamboozled          2000
# 11                   Cast Away          2000
# 12                    Chocolat          2000
# 13          Dancer in the Dark          2000
# 14             Erin Brockovich          2000
# 15           Finding Forrester          2000
# 16                        Fiza          2000
# 17                   Gladiator          2000
# 18       Gone in Sixty Seconds          2000
# 19           Keeping the Faith          2000
# ...

# %%
select title, language from cinema.films where language in ('English', 'Spanish', 'French')
# Out:
#                     title language
# 0     The Broadway Melody  English
# 1           Hell's Angels  English
# 2      A Farewell to Arms  English
# 3             42nd Street  English
# 4      She Done Him Wrong  English
# ...                   ...      ...
# 4742              Twisted  English
# 4743          Unforgotten  English
# 4744                Wings  English
# 4745           Wolf Creek  English
# 4746    Wuthering Heights  English
#
# [4747 rows x 2 columns]

# %%
select title, certification from cinema.films where certification in ('NC-17', 'R')
# Out:
#                          title certification
# 0                       Psycho             R
# 1         A Fistful of Dollars             R
# 2              Rosemary's Baby             R
# 3          Mississippi Mermaid             R
# 4               The Wild Bunch             R
# ...                        ...           ...
# 2120            The Neon Demon             R
# 2121         The Perfect Match             R
# 2122  The Purge: Election Year             R
# 2123                  The Veil             R
# 2124                  Triple 9             R
#
# [2125 rows x 2 columns]

# %%
SELECT COUNT(*) FROM cinema.people WHERE birthdate IS NULL;
# Out:
#    count
# 0   2245

# %%
SELECT name,deathdate from cinema.people where deathdate IS NULL
# Out:
#                     name  deathdate
# 0                50 Cent        NaN
# 1     A. Michael Baldwin        NaN
# 2          A. Raven Cruz        NaN
# 3           A.J. Buckley        NaN
# 4           A.J. DeLucia        NaN
# ...                  ...        ...
# 7605         Zoey Deutch        NaN
# 7606     Zooey Deschanel        NaN
# 7607       Zoran Lisinac        NaN
# 7608       Zubaida Sahar        NaN
# 7609       Zuhair Haddad        NaN
#
# [7610 rows x 2 columns]

# %%
select title,budget from cinema.filmS where budget IS NULL
# Out:
#                        title  budget
# 0              Pandora's Box     NaN
# 1      The Prisoner of Zenda     NaN
# 2              The Blue Bird     NaN
# 3                      Bambi     NaN
# 4                 State Fair     NaN
# ..                       ...     ...
# 425              Unforgotten     NaN
# 426                    Wings     NaN
# 427               Wolf Creek     NaN
# 428        Wuthering Heights     NaN
# 429  Yu-Gi-Oh! Duel Monsters     NaN
#
# [430 rows x 2 columns]

# %%
select count(*) from cinema.films where language is null
# Out:
#    count
# 0      0

# %%
select name from cinema.people where name like 'B%' --inicia con B
# Out:
#                name
# 0        B.J. Novak
# 1      Babak Najafi
# 2       Babar Ahmed
# 3    Bahare Seddiqi
# 4          Bai Ling
# ..              ...
# 440   Buster Keaton
# 441   Busy Philipps
# 442     Buzz Aldrin
# 443    Byron Howard
# 444      Byron Mann
#
# [445 rows x 1 columns]

# %%
select name from cinema.people where name like '_r%' --segundo caracter sea 'r'
# Out:
#                   name
# 0             Ara Celi
# 1        Aramis Knight
# 2    Arben Bajraktaraj
# 3      Arcelia Ramírez
# 4           Archie Kao
# ..                 ...
# 526        Troy Garity
# 527        Troy Miller
# 528         Troy Nixey
# 529     Ursula Andress
# 530      Wray Crawford
#
# [531 rows x 1 columns]

# %%
select name from cinema.people where name not like 'A%' --no empiecen por A
# Out:
#                     name
# 0                50 Cent
# 1            Álex Angulo
# 2     Álex de la Iglesia
# 3          Ángela Molina
# 4             B.J. Novak
# ...                  ...
# 7763         Zohra Segal
# 7764     Zooey Deschanel
# 7765       Zoran Lisinac
# 7766       Zubaida Sahar
# 7767       Zuhair Haddad
#
# [7768 rows x 1 columns]
